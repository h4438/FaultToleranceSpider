# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)

file = "../ver3/train.jsonl"
df = pd.read_json(file, lines=True)
df.shape
# Out:
# (54965, 8)

# %%
sdf = df[df["group_id"] == 11]
sdf.head(7)
# Out:
#                                                                                                                                                                         title  \
# 6      ##### Khai giảng Khóa 03 đào tạo trình độ đại học chính quy tuyển mới đối với công dân đã có bằng tốt nghiệp trình độ đại học trở lên mở tại Học viện An ninh nhân dân
# 7      ##### Khai giảng Khóa 03 đào tạo trình độ đại học chính quy tuyển mới đối với công dân đã có bằng tốt nghiệp trình độ đại học trở lên mở tại Học viện An ninh nhân dân
# 9883                                                                                              # THÔNG BÁO TUYỂN SINH VÀ ĐÀO TẠO TRÌNH ĐỘ CHUYÊN KHOA CẤP I ĐỢT 2 NĂM 2023
# 9884                                                                                              # THÔNG BÁO TUYỂN SINH VÀ ĐÀO TẠO TRÌNH ĐỘ CHUYÊN KHOA CẤP I ĐỢT 2 NĂM 2023
# ...
